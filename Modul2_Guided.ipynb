# %% [markdown]
# <a href="https://colab.research.google.com/github/JetiAprilia9/IPSD-Assignment/blob/main/Modul2_Guided.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Movie_classification - Movie_classification.csv")

# %%
import pandas as pd
df = pd.read_csv('/content/Iris - Iris.csv')

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.describe().T
# Out:
#                count       mean        std  min    25%    50%     75%    max
# Id             150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# SepalLengthCm  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# SepalWidthCm   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# PetalLengthCm  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# PetalWidthCm   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %%
import pandas as pd
df = pd.read_csv("/content/Movie_classification - Movie_classification.csv")

# %%
df.describe()
# Out:
#        Production expense  Multiplex coverage  Movie_length  \
# count          506.000000          506.000000    506.000000
# mean            77.273557          382.999097    142.074901
# std             13.720706          192.003636     28.148861
# min             55.920000            0.230000     76.400000
# 25%             65.380000          307.000000    118.525000
# 50%             74.380000          453.000000    151.000000
# 75%             91.200000          536.000000    167.575000
# max            110.480000          615.000000    173.500000
#
#        Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# count          506.000000           506.000000       506.000000
# mean             8.014002             8.185613         8.019664
# std              1.054266             1.054290         1.059899
# min              3.840000             4.035000         3.840000
# 25%              7.316250             7.503750         7.296250
# ...

# %%
df.describe()
# Out:
#        Production expense  Multiplex coverage  Movie_length  \
# count          506.000000          506.000000    506.000000
# mean            77.273557          382.999097    142.074901
# std             13.720706          192.003636     28.148861
# min             55.920000            0.230000     76.400000
# 25%             65.380000          307.000000    118.525000
# 50%             74.380000          453.000000    151.000000
# 75%             91.200000          536.000000    167.575000
# max            110.480000          615.000000    173.500000
#
#        Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# count          506.000000           506.000000       506.000000
# mean             8.014002             8.185613         8.019664
# std              1.054266             1.054290         1.059899
# min              3.840000             4.035000         3.840000
# 25%              7.316250             7.503750         7.296250
# ...

# %%
df.describe().T
# Out:
#                      count           mean           std         min  \
# Production expense   506.0      77.273557     13.720706      55.920
# Multiplex coverage   506.0     382.999097    192.003636       0.230
# Movie_length         506.0     142.074901     28.148861      76.400
# Lead_ Actor_Rating   506.0       8.014002      1.054266       3.840
# Lead_Actress_rating  506.0       8.185613      1.054290       4.035
# Director_rating      506.0       8.019664      1.059899       3.840
# Producer_rating      506.0       8.190514      1.049601       4.030
# Critic_rating        506.0       7.810870      0.659699       6.600
# Trailer_views        506.0  449860.715415  68917.763145  212912.000
# Time_taken           494.0     157.391498     31.295161       0.000
# Twitter_hastags      506.0     260.832095    104.779133     201.152
# Avg_age_actors       506.0      39.181818     12.513697       3.000
# Num_multiplex        506.0     545.043478    106.332889     333.000
# ...

# %%
df.isna().sum()
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Start_Tech_Oscar        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Start_Tech_Oscar        0
# dtype: int64

# %%
df.shape # melihat ukuran data (baris, kolom)
# Out:
# (506, 19)

# %%
df.dtypes
# Out:
# Marketing expense       object
# Production expense     float64
# Multiplex coverage     float64
# Budget                  object
# Movie_length           float64
# Lead_ Actor_Rating     float64
# Lead_Actress_rating    float64
# Director_rating        float64
# Producer_rating        float64
# Critic_rating          float64
# Trailer_views            int64
# 3D_available            object
# Time_taken             float64
# Twitter_hastags        float64
# Genre                   object
# Avg_age_actors           int64
# Num_multiplex            int64
# Collection               int64
# Start_Tech_Oscar         int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()/len (df)*100
# Out:
# Marketing expense      0.000000
# Production expense     0.000000
# Multiplex coverage     0.000000
# Budget                 0.000000
# Movie_length           0.000000
# Lead_ Actor_Rating     0.000000
# Lead_Actress_rating    0.000000
# Director_rating        0.000000
# Producer_rating        0.000000
# Critic_rating          0.000000
# Trailer_views          0.000000
# 3D_available           0.000000
# Time_taken             2.371542
# Twitter_hastags        0.000000
# Genre                  0.000000
# Avg_age_actors         0.000000
# Num_multiplex          0.000000
# Collection             0.000000
# Start_Tech_Oscar       0.000000
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.dropna(inplace=False)
# Out:
#     Marketing expense  Production expense  Multiplex coverage      Budget  \
# 0             201.264               59.62               462.0  36.524.125
# 1             205.462               69.14               531.0  35.668.655
# 2             205.458               69.14               531.0  39.912.675
# 3             206.474               59.36               542.0    38873.89
# 4              21.381               59.36               542.0  39.701.585
# ..                ...                 ...                 ...         ...
# 501           212.526               78.86               427.0  36.624.115
# 502           209.054               78.86               427.0     33996.6
# 503           212.152               78.86               427.0    38751.68
# 504           221.918               78.86               427.0    37740.67
# 505           209.482               78.86               427.0    33496.65
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
a= df.copy(deep= True)

# %%
a.dropna(inplace=True)

# %%
a.dropna(inplace=False)
# Out:
#     Marketing expense  Production expense  Multiplex coverage      Budget  \
# 0             201.264               59.62               462.0  36.524.125
# 1             205.462               69.14               531.0  35.668.655
# 2             205.458               69.14               531.0  39.912.675
# 3             206.474               59.36               542.0    38873.89
# 4              21.381               59.36               542.0  39.701.585
# ..                ...                 ...                 ...         ...
# 501           212.526               78.86               427.0  36.624.115
# 502           209.054               78.86               427.0     33996.6
# 503           212.152               78.86               427.0    38751.68
# 504           221.918               78.86               427.0    37740.67
# 505           209.482               78.86               427.0    33496.65
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
# import package pandas dan membaca dataset

# %%
df.to_excel("/content/Movie_classification - Movie_classification.xlsx", index=False)

# %%
bebas = pd.read_excel("/content/Movie_classification - Movie_classification.xlsx")
bebas.head()
# Out:
#   Marketing expense  Production expense  Multiplex coverage      Budget  \
# 0           201.264               59.62               462.0  36.524.125
# 1           205.462               69.14               531.0  35.668.655
# 2           205.458               69.14               531.0  39.912.675
# 3           206.474               59.36               542.0    38873.89
# 4            21.381               59.36               542.0  39.701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
# impoerting package pandas dan membaca dataset Iris
import pandas as pd
iris_filename = '/content/Iris - Iris.csv'
iris = pd.read_csv(iris_filename, sep=',',
                  decimal='.', header=None,
                   names= ['septal_length',
                    'septal_width',
                    'petal_length',
                    'petal_width',
                    'target'])

# %%
#untuk mengetahui nama kolom
iris.columns
# Out:
# Index(['septal_length', 'septal_width', 'petal_length', 'petal_width',
#        'target'],
#       dtype='object')

# %%
iris['target']
# Out:
# Id            Species
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# 150    Iris-virginica
# Name: target, Length: 151, dtype: object

# %%
iris.target #nama variable.nama kolom, tetapi hanya berlaku untuk nama kolom yang tanpa spasi
# Out:
# Id            Species
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# 150    Iris-virginica
# Name: target, Length: 151, dtype: object

# %%
# mengatur kolom "target" sebagai indeks ubah kolom "target" menjadi indeks dari dataset
iris.set_index('target', inplace=True)
print(iris.head())
# Out:
#              septal_length  septal_width   petal_length   petal_width
# target
# Species      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Iris-setosa           5.10          3.50           1.40          0.20
# Iris-setosa           4.90          3.00           1.40          0.20
# Iris-setosa           4.70          3.20           1.30          0.20
# Iris-setosa           4.60          3.10           1.50          0.20

# %%
# menghapus indeks yang telah dibuat
iris.reset_index(drop=True, inplace=True)

# %%
# membaca dataset iris
iris_filename = '/content/Iris - Iris.csv'
iris = pd.read_csv(iris_filename)

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Melakukan operasi aritmatika
#Hitung perbandingan antara panjang dan lebar sepal untuk setiap target,
iris['sepal_ratio'] = iris['SepalLengthCm'] / iris['SepalWidthCm'] # fixed typo in co.
print(iris.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    sepal_ratio
# 0     1.457143
# 1     1.633333
# 2     1.468750
# 3     1.483871
# 4     1.388889

# %%
#menggunakan .apply() untuk operasi kustom hitung luas petal (panjang petal x lebar petal) untuk setiap target
# dan tambahkan hasilnya ke dataframe sebagai kolom baru "petal_area".
iris['petal_area'] = iris.apply(lambda row: row['PetalWidthCm'], axis=1)
